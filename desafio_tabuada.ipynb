# %%
#tabua destruidor de numeros 


def inicio_tabuada():
    x = int(input('digite o numero para tabuada?'))
    
    return x

# %%
numero = inicio_tabuada()

# %%
numero
# Out:
# 3

# %%
def funcao_multiplica():
    resultado = numero * 2
    print (resultado)

# %%
funcao_multiplica()

# %%
def funcao_somar():
    resultado = inicio_tabuada() + 2
    print (resultado)

# %%
funcao_somar()

# %%
inicio_tabuada()

# %%
def funcao_sub():
    resultado = inicio_tabuada() - 2
    print (resultado)

# %%
#funcao_sub()
print(numero)

# %%
for i in range(11): # range 0,1,2,3,4...10
  
   x = numero * i
   #x2 = x * i
   #res = i + 1
   #res2 = res * i

   print(f' {numero} x {i} = {x}')
# Out:
#  3 x 0 = 0
#  3 x 1 = 3
#  3 x 2 = 6
#  3 x 3 = 9
#  3 x 4 = 12
#  3 x 5 = 15
#  3 x 6 = 18
#  3 x 7 = 21
#  3 x 8 = 24
#  3 x 9 = 27
#  3 x 10 = 30

# %%
for i in range(11):
    x = numero * i
    print(x)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
